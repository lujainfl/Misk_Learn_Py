# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %%
cars1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv")

cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %%
cars2 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv")
cars2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# 4       1       amc pacer d/l

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.drop(("Unnamed: 9" , axis=1))
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
cars1 = cars1.drop(["Unnamed: 9", "Unnamed: 10",
 "Unnamed: 11","Unnamed: 12","Unnamed: 13"], axis=1)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %%
cars1 = cars1.loc[:, "mpg":"car"]

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print(cars1.shape)
print(cars2.shape)
# Out:
# (198, 9)
# (200, 9)

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars2.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin              car
# 195       1  ford mustang gl
# 196       2        vw pickup
# 197       1    dodge rampage
# 198       1      ford ranger
# 199       1       chevy s-10

# %%
cars = cars1.append(cars2)
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    int64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model         398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car           398 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 31.1+ KB

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
nr_owners = np.random.randint(15000, high= 73001, size=398, dtype='l')
nr_owners
# Out:
# array([38785, 61571, 69188, 46118, 69505, 36306, 23744, 19909, 18031,
#        37787, 17414, 36200, 64212, 49612, 26474, 32879, 43001, 35979,
#        51741, 29562, 62841, 28653, 20373, 17286, 56220, 19485, 47338,
#        64874, 67402, 21851, 57225, 36273, 71174, 39515, 37901, 29546,
#        20544, 53075, 34812, 30164, 60259, 60489, 50399, 67597, 63410,
#        51993, 35177, 27690, 37922, 65375, 26840, 56918, 40064, 55761,
#        19961, 61037, 18497, 17950, 24607, 64275, 31260, 57904, 52274,
#        50467, 23077, 66727, 39519, 68157, 18728, 15507, 40714, 59836,
#        26978, 70578, 47182, 27636, 25700, 42587, 56183, 31038, 41358,
#        23462, 26030, 47902, 48848, 54745, 30963, 24050, 37683, 50428,
#        17011, 31701, 67303, 36143, 64869, 17950, 63203, 24092, 24058,
#        32383, 40198, 49994, 19187, 63351, 45174, 30037, 39935, 35568,
#        72738, 43628, 32948, 19984, 56400, 24315, 15251, 29716, 37599,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners'] = 0

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# ...

# %%
cars['owners'] = nr_owners

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# ...

# %%
def to_kg(x):
    return int(x/2.2)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  owners
# 0       1  chevrolet chevelle malibu   38785
# 1       1          buick skylark 320   61571
# 2       1         plymouth satellite   69188
# 3       1              amc rebel sst   46118
# 4       1                ford torino   69505

# %%
cars["weight_kg"] = cars['weight'].apply(to_kg)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  owners  weight_kg
# 0       1  chevrolet chevelle malibu   38785       1592
# 1       1          buick skylark 320   61571       1678
# 2       1         plymouth satellite   69188       1561
# 3       1              amc rebel sst   46118       1560
# 4       1                ford torino   69505       1567

# %%
func = lambda x:x/2.2
func(2.2)
# Out:
# 1.0

# %%
cars['wt_kg'] = cars['weight'].apply(lambda x: int(x/2.2)+1)

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
# ...

# %%
def is_heavy(x):
    try: 
        if x > 1500:
            return "1"
        else: return "0"
    except:
        return None

# %%
cars["is_heavy"] = cars['weight_kg'].apply(is_heavy)

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners  weight_kg is_heavy
# ...

# %%
cars["trial"] = cars['car'].apply(is_heavy)

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    int64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model         398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car           398 non-null    object
#  9   owners        398 non-null    int64
#  10  weight_kg     398 non-null    int64
#  11  is_heavy      398 non-null    object
#  12  trial         0 non-null      object
# dtypes: float64(2), int64(7), object(4)
# memory usage: 43.5+ KB

# %%
cars.acceleration.map(int)
# Out:
# 0      12
# 1      11
# 2      11
# 3      12
# 4      10
#        ..
# 195    15
# 196    24
# 197    11
# 198    18
# 199    19
# Name: acceleration, Length: 398, dtype: int64

# %%
def times10(x):
    if type(x) is int:
        return 10 * x
    return x

# %%
cars.applymap(times10).head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0         80          3070        130   35040          12.0    700
# 1  15.0         80          3500        165   36930          11.5    700
# 2  18.0         80          3180        150   34360          11.0    700
# 3  16.0         80          3040        150   34330          12.0    700
# 4  17.0         80          3020        140   34490          10.5    700
#
#    origin                        car  owners  weight_kg is_heavy trial  wt_kg
# 0      10  chevrolet chevelle malibu  387850      15920        1  None  15930
# 1      10          buick skylark 320  615710      16780        1  None  16790
# 2      10         plymouth satellite  691880      15610        1  None  15620
# 3      10              amc rebel sst  461180      15600        1  None  15610
# 4      10                ford torino  695050      15670        1  None  15680

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
cars["is_heavy"] = cars['weight_kg'].progress_apply(is_heavy)
# Out:
# 100%|██████████| 398/398 [00:00<00:00, 664278.95it/s]
